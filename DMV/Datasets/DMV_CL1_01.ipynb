# %%
import pandas as pd
data = pd.read_csv(r"Datasets\supermarket_sales - Sheet1 (1).csv")
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data_excel = pd.read_excel(r"Datasets\Superstore (1).xlsx")
data_excel.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data_excel.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
data_json = pd.read_json(r"Datasets\StoreSales (1).json",
                         encoding='utf-8',
                         encoding_errors='ignore')
data_json.head()
# Out:
#   Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0  32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1  26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2  25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3  13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4  47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
new_data = data_json.iloc[1:3]
new_data
# Out:
#   Row ID       Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 1  26341  IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2  25330  IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
#
#    Customer Name    Segment        City            State  ...  \
# 1  Justin Ritter  Corporate  Wollongong  New South Wales  ...
# 2   Craig Reiter   Consumer    Brisbane       Queensland  ...
#
#         Product ID    Category Sub-Category  \
# 1  FUR-CH-10003950   Furniture       Chairs
# 2  TEC-PH-10004664  Technology       Phones
#
#                                 Product Name     Sales Quantity Discount  \
# 1  Novimex Executive Leather Armchair, Black  3709.395      9.0      0.1
# 2          Nokia Smart Phone, with Caller ID  5175.171      9.0      0.1
#
#     Profit  Shipping Cost  Order Priority
# 1 -288.765         923.63        Critical
# 2  919.971         915.49          Medium
#
# [2 rows x 24 columns]

# %%
merged_data = data_json.merge(data_json,how='outer',on='Row ID')
merged_data
# Out:
#       Row ID      Order ID_x Order Date_x Ship Date_x     Ship Mode_x  \
# 0                        NaN          NaN         NaN             NaN
# 1          1  MX-2014-143658   02-10-2014  06-10-2014  Standard Class
# 2         10  MX-2013-134096   27-09-2013  01-10-2013  Standard Class
# 3        100  US-2013-125892   08-08-2013  10-08-2013     First Class
# 4       1000  MX-2013-126361   17-12-2013  19-12-2013    Second Class
# ...      ...             ...          ...         ...             ...
# 51286   9995  US-2014-110667   02-10-2014  06-10-2014  Standard Class
# 51287   9996  US-2012-142734   15-10-2012  20-10-2012  Standard Class
# 51288   9997  US-2012-142734   15-10-2012  20-10-2012  Standard Class
# 51289   9998  US-2012-142734   15-10-2012  20-10-2012  Standard Class
# 51290   9999  US-2012-142734   15-10-2012  20-10-2012  Standard Class
#
#       Customer ID_x Customer Name_x  Segment_x         City_x  \
# 0               NaN             NaN        NaN            NaN
# ...

# %%
data_json.shape
# Out:
# (51291, 24)

# %%
data_excel.shape
# Out:
# (9994, 21)

# %%
data_json.describe
# Out:
# <bound method NDFrame.describe of       Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0      32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1      26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2      25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3      13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4      47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...      ...              ...         ...         ...             ...
# 51286  35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287  40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288   9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289   6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
# 51290                     NaN         NaN         NaN             NaN
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
print("Total no of sales: ")
round(data_json['Sales'].sum())
# Out:
# Total no of sales:
# 12642502

# %%
data_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51291 entries, 0 to 51290
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51291 non-null  object
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     51290 non-null  object
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
print("Average order value: ")
(data['Unit price']* data['Quantity']).mean()
# Out:
# Average order value:
# np.float64(307.58738)

# %%
data_json.isnull().sum()
# Out:
# Row ID            0
# Order ID          1
# Order Date        1
# Ship Date         1
# Ship Mode         1
# Customer ID       1
# Customer Name     1
# Segment           1
# City              1
# State             1
# Country           1
# Postal Code       1
# Market            1
# Region            1
# Product ID        1
# Category          1
# Sub-Category      1
# Product Name      1
# Sales             1
# Quantity          1
# Discount          1
# Profit            1
# Shipping Cost     1
# Order Priority    1
# dtype: int64

# %%
data_json.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
new_data = data_json.groupby('Category')
x = new_data['Quantity'].count().index
y = new_data['Quantity'].count().values

# %%
x
# Out:
# Index(['Furniture', 'Office Supplies', 'Technology'], dtype='object', name='Category')

# %%
y
# Out:
# array([ 9876, 31273, 10141])

# %%
sns.barplot(x=x,y=y)
plt.xlabel("Category")
plt.ylabel("No of products")
plt.show()

# %%
grouped_data = data_json.groupby('Category')
grouped_data.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# 5   22732    IN-2013-42360  28-06-2013  01-07-2013    Second Class
# 6   30570    IN-2011-81826  07-11-2011  09-11-2011     First Class
# 7   31192    IN-2012-86369  14-04-2012  18-04-2012  Standard Class
# 8   40155   CA-2014-135909  14-10-2014  21-10-2014  Standard Class
# 9   40936   CA-2012-116638  28-01-2012  31-01-2012    Second Class
# 10  34577   CA-2011-102988  05-04-2011  09-04-2011    Second Class
# 11  28879    ID-2012-28402  19-04-2012  22-04-2012     First Class
# 14  27704    IN-2013-73951  06-06-2013  08-06-2013    Second Class
# ...

# %%
x = grouped_data['Sales'].sum()

# %%
data_json.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
x
# Out:
# Category
# Furniture          4.110874e+06
# Office Supplies    3.787070e+06
# Technology         4.744557e+06
# Name: Sales, dtype: float64

# %%
x.index
# Out:
# Index(['Furniture', 'Office Supplies', 'Technology'], dtype='object', name='Category')

# %%
import numpy as np
labels = np.array(x.index)
type(labels)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
plt.pie(abs(x.values),labels = labels,autopct="%.2f%%")
plt.show()

# %%
state = data_json.groupby (['State', 'City'])
y = abs (state['Sales'].sum())
y= y.reset_index()
y= y.sort_values (by="Sales", ascending=False)

# %%
import seaborn as sns
sns.barplot(x = y['City'] [:5], y = y ['Sales'] [:5])
plt.show()

# %%
import pandas as pd
data = pd.read_csv(r"Datasets\supermarket_sales - Sheet1 (1).csv")
data.head()
data.isnull().sum()

data_excel = pd.read_excel(r"Datasets\Superstore (1).xlsx")
data_excel.head()
data_excel.isnull().sum

data_json = pd.read_json(r"Datasets\StoreSales (1).json",
                         encoding='utf-8',
                         encoding_errors='ignore')
data_json.head()


new_data = data_json.iloc[1:3]
new_data
merged_data = data_json.merge(data_json,how='outer',on='Row ID')
merged_data

data_json.shape
data_excel.shape
data_json.describe
data.describe

print("Total no of sales: ")
round(data_json['Sales'].sum())
data_json.info()

print("Average order value: ")
(data['Unit price']* data['Quantity']).mean()

data_json.isnull().sum()
data_json.dropna(inplace=True)


import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
new_data = data_json.groupby('Category')
x = new_data['Quantity'].count().index
y = new_data['Quantity'].count().values
x
y


sns.barplot(x=x,y=y)
plt.xlabel("Category")
plt.ylabel("No of products")
plt.show()

grouped_data = data_json.groupby('Category')
grouped_data.head()

x = grouped_data['Sales'].sum()

data_json.columns
x
x.index
import numpy as np
labels = np.array(x.index)
type(labels)

import matplotlib.pyplot as plt
plt.pie(abs(x.values),labels = labels,autopct="%.2f%%")
plt.show()

state = data_json.groupby (['State', 'City'])
y = abs (state['Sales'].sum())
y= y.reset_index()
y= y.sort_values (by="Sales", ascending=False)

import seaborn as sns
sns.barplot(x = y['City'] [:5], y = y ['Sales'] [:5])
plt.show()
# Out:
# Total no of sales:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51291 entries, 0 to 51290
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51291 non-null  object
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     51290 non-null  object
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...
